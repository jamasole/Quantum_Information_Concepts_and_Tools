# %% [markdown]
# <figure>
# <a id='fig_ref'></a>
# <img src="images/logos/logo_usc.jpg" align=right width='120px'/>
# </figure>
#
# <br>
# <br>
# <br>
# <br>
#
# <table width="100%"><td style=" font_style:italic; font-size:50px;text-align:center;background-color:rgba(0, 220, 170,0.7)">
# <div>
# Quantum Information Concepts and Tools
# </div>
# </td></table>
#
#
#
#
# February 2026
#
# Javier Mas Solé
#
#
# <br>
# <br>
#
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img aling="left" alt="Licencia Creative Commons" style="border-width:0" src="https://i.creativecommons.org/l/by-sa/4.0/88x31.png" /></a><br />License: <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">Licencia Creative Commons Atribución-CompartirIgual 4.0 Internacional</a>.

# %% [markdown]
# [**Bibliography**](Bibliography.ipynb#fund)
#
#
#
#
# ## The rules of the game
#
#
# - ###  [Complex Numbers](01_The_rules_of_the_game/011_Complex_Numbers.ipynb)
# - ###  [Vectors](01_The_rules_of_the_game/012_Vectors.ipynb)
# - ###  [Operators](01_The_rules_of_the_game/013_Operators.ipynb)
# - ###  [Tensors](01_The_rules_of_the_game/014_Tensors.ipynb)
# - ###  [Probabilities](01_The_rules_of_the_game/015_Probabilities.ipynb)
#
# - ###  [Fundamentals of Quantum Mechanics](01_Formalism/016_QM_Fundaments.ipynb)

# %% [markdown]
# ## Dancing with qubits
#
# - ###  [The qubit](02_Dancing_with_qubits/021_Qubits.ipynb)
# - ###  [Physical qubits: spin](02_Dancing_with_qubits/022_Spin.ipynb)
# - ###  [The art of measuring I](02_Dancing_with_qubits/023_MeasurementI.ipynb)
# - ###  [Multi-qubits](02_Dancing_with_qubits/024_Multiqubits.ipynb)
# - ###  [The art of measuring II](02_Dancing_with_qubits/025_MeasurementII.ipynb)

# %% [markdown]
# ## Basic quantum computing
#
# - ###  [Elementary quantum circuitry](03_Basic_quantum_computing/031_Basic_Circuits.ipynb)
# - ###  [Quantum circuits for classical computing](03_Basic_quantum_computing/032_Classical_Comp.ipynb)
# - ###  [Oracle algorithms](03_Basic_quantum_computing/033_Oracle_algorithms.ipynb)
# - ###  [Quantum Fourier transform](03_Basics_quantum_computing/034_QFT.ipynb)
# - ###  [Quantum phase estimation](03_Basic_quantum_computing/035_QPE.ipynb)
# - ###  [Search algorithms](03_Basics_quantum_computing/036_Search_algo.ipynb)

# %% [markdown]
# ## Topics in quantum mechanics
#
# - ###  [Entanglement in action](04_Topics_in_quantum_mechanics/041_Entanglement.ipynb)
# - ###  [Mixed quantum states](04_Topics_in_quantum_mechanics/042_Density_Operator_en.ipynb)
# - ###  [Open quantum systems](04_Topics_in_quantum_mechanics/043_Open_Quantum_Systems.ipynb)
# - ###  [Generalized measurements](04_Topics_in_quantum_mechanics/044_General_Measurement.ipynb)

# %% [markdown]
# ## Elements of quantum information
#
# - ###  [Classical information theory](05_Elements_of_quantum_information/051_Classical_Info.ipynb)
# - ###  [Quantum information theory](05_Elements_of_quantum_information/052_Quantum_Info.ipynb)

# %% [markdown]
# ## Quantum Communication
#
#
#
# ## Quantum Simulation
